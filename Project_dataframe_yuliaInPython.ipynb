# %%
import pandas as pd

# %% [markdown]
# #Read from CSV File

# %%
df = pd.read_csv("/content/drive/MyDrive/DIGITAL_SKOLA/student-math.csv")
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# #Data Inspecting

# %%
#5 first of data
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   nursery higher  internet  freetime  goout Dalc absences  G1  G2  G3
# 0     yes    yes        no         3      4    1        6   5   6   6
# 1      no    yes       yes         3      3    1        4   5   5   6
# 2     yes    yes       yes         3      2    2       10   7   8  10
# 3     yes    yes       yes         2      2    1        2  15  14  15
# 4     yes    yes        no         3      2    1        4   6  10  10
#
# [5 rows x 29 columns]

# %%
#5 last of data
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... nursery higher  internet  freetime  goout Dalc absences  G1  G2  G3
# 390  ...     yes    yes        no         5      4    4       11   9   9   9
# 391  ...      no    yes       yes         4      5    3        3  14  16  16
# 392  ...      no    yes        no         5      3    3        3  10   8   7
# 393  ...      no    yes       yes         4      1    3        0  11  12  10
# 394  ...     yes    yes       yes         2      3    3        5   8   9   9
#
# [5 rows x 29 columns]

# %%
#list of column name
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'freetime', 'goout', 'Dalc', 'absences', 'G1',
#        'G2', 'G3'],
#       dtype='object')

# %%
#data size (number of row and column)
df.shape
# Out:
# (395, 29)

# %%
#describe descriptive statistics of numerical data
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#          freetime       goout        Dalc    absences          G1          G2  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.235443    3.108861    1.481013    5.708861   10.908861   10.713924
# ...

# %%
#describe descriptive statistics of categorical data
df.describe(include=["object", "bool"])
# Out:
#        school  sex address famsize Pstatus   Mjob   Fjob  reason guardian  \
# count     395  395     395     395     395    395    395     395      395
# unique      2    2       2       2       2      5      5       4        3
# top        GP    F       U     GT3       T  other  other  course   mother
# freq      349  208     307     281     354    141    217     145      273
#
#        schoolsup famsup paid activities nursery higher internet
# count        395    395  395        395     395    395      395
# unique         2      2    2          2       2      2        2
# top           no    yes   no        yes     yes    yes      yes
# freq         344    242  214        201     314    375      329

# %% [markdown]
# #TASK OF THE MINI PROJECT

# %% [markdown]
# **1. Nilai rata-rata akhir (G3) semua murid di sekolah GP**

# %%
df["school"] == "GP"
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 390    False
# 391    False
# 392    False
# 393    False
# 394    False
# Name: school, Length: 395, dtype: bool

# %%
#subsetting to display suitable data
anak_gp = df[df["school"] == "GP"]
anak_gp
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1  at_home     other
# 2       GP   F   15       U     LE3       T     1     1  at_home     other
# 3       GP   F   15       U     GT3       T     4     2   health  services
# 4       GP   F   16       U     GT3       T     3     3    other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...       ...
# 344     GP   F   18       U     GT3       T     2     3  at_home     other
# 345     GP   F   18       U     GT3       T     3     2    other  services
# 346     GP   M   18       R     GT3       T     4     3  teacher  services
# 347     GP   M   18       U     GT3       T     4     3  teacher     other
# 348     GP   F   17       U     GT3       T     4     3   health     other
#
# ...

# %%
anak_gp_mean = anak_gp["G3"].mean()
anak_gp_mean = round(anak_gp_mean, 2)
print("Nilai rata-rata akhir (G3) semua murid di sekolah 'GP':", anak_gp_mean)
# Out:
# Nilai rata-rata akhir (G3) semua murid di sekolah 'GP': 10.49

# %% [markdown]
# **2. Nilai min dan max (G3) dari murid di sekolah "MS"**

# %%
g3_ms = df[df["school"] == "MS"]["G3"]
min_g3_ms = g3_ms.min()
max_g3_ms = g3_ms.max()

print("Nilai terendah dari murid di sekolah MS:", min_g3_ms)
print("Nilai tertinggi dari murid di sekolah MS:", max_g3_ms)
# Out:
# Nilai terendah dari murid di sekolah MS: 0
# Nilai tertinggi dari murid di sekolah MS: 19

# %% [markdown]
# **3. Proporsi jenis kelamin dari murid-murid dalam persentase**

# %%
#checking the value of column sex
df["sex"]
# Out:
# 0      F
# 1      F
# 2      F
# 3      F
# 4      F
#       ..
# 390    M
# 391    M
# 392    M
# 393    M
# 394    M
# Name: sex, Length: 395, dtype: object

# %%
#count the number of each value by groupby
df.groupby("sex")["age"].count()
# Out:
# sex
# F    208
# M    187
# Name: age, dtype: int64

# %%
#count the number of each value by value_counts
df["sex"].value_counts()
# Out:
# F    208
# M    187
# Name: sex, dtype: int64

# %%
#count the proportion
df["sex"].value_counts() / len(df)
# Out:
# F    0.526582
# M    0.473418
# Name: sex, dtype: float64

# %%
#count the proportion on percentage and round it
round((df["sex"].value_counts() / len(df)) * 100, 2)
# Out:
# F    52.66
# M    47.34
# Name: sex, dtype: float64

# %% [markdown]
# **3.1 Proporsi jenis kelamin dari murid-murid dari masing-masing sekolah dalam persentase**

# %%
#grouping by school
df.groupby("school")["sex"].count()
# Out:
# school
# GP    349
# MS     46
# Name: sex, dtype: int64

# %%
#count the sex proportion on percentage and round it
round((df.groupby("school")["sex"].value_counts() / len(df)) * 100, 2)
# Out:
# school  sex
# GP      F      46.33
#         M      42.03
# MS      F       6.33
#         M       5.32
# Name: sex, dtype: float64

# %% [markdown]
# **4. Rata-rata final grade (G3) sesuai dengan study time**
#
#   studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)

# %%
#grouping by study time to get info of G3 mean for each category
df.groupby("studytime")["G3"].mean()
# Out:
# studytime
# 1    10.047619
# 2    10.171717
# 3    11.400000
# 4    11.259259
# Name: G3, dtype: float64

# %%
df.groupby("studytime").agg({"G3": 'mean'})
# Out:
#                   G3
# studytime
# 1          10.047619
# 2          10.171717
# 3          11.400000
# 4          11.259259

# %% [markdown]
# **5. Rata-rata final grade (G3) sesuai dengan extra educational support**
#
#   schoolsup - extra educational support (binary: yes or no)

# %%
#grouping by schollsup  to get info of G3 mean for each category
df.groupby("schoolsup")["G3"].mean()
# Out:
# schoolsup
# no     10.561047
# yes     9.431373
# Name: G3, dtype: float64

# %%
df.groupby("schoolsup").agg({"G3": 'mean'})
# Out:
#                   G3
# schoolsup
# no         10.561047
# yes         9.431373

# %% [markdown]
# **6. Rata-rata jumlah bolos (absen) sesuai dengan jumlah kegagalan**
#
#   failures - number of past class failures (numeric: n if 1<=n<3, else 4)
#
#   absences - number of school absences (numeric: from 0 to 93)

# %%
#grouping by failures  to get info of absences mean for each category
df.groupby("failures")["absences"].mean()
# Out:
# failures
# 0    5.134615
# 1    9.420000
# 2    6.705882
# 3    4.250000
# Name: absences, dtype: float64

# %%
#absence isn't suitable in float type, need to round the value
round(df.groupby("failures")["absences"].mean(), 0)
# Out:
# failures
# 0    5.0
# 1    9.0
# 2    7.0
# 3    4.0
# Name: absences, dtype: float64

# %%
df.groupby("failures").agg({"absences": 'mean'})
# Out:
#           absences
# failures
# 0         5.134615
# 1         9.420000
# 2         6.705882
# 3         4.250000

# %% [markdown]
# **7. Jumlah anak yang meningkat skor ujiannya (first vs. final)**

# %%
#score is considered to increase if last scores G3 greater than first scores G1
df["G3"] > df["G1"]
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 390    False
# 391     True
# 392    False
# 393    False
# 394     True
# Length: 395, dtype: bool

# %%
#subsetting to get the number of the data that suitable
sum_stud = df[df["G3"] > df["G1"]]["age"].count()
print("Jumlah anak yang meningkat skor ujiannya adalah", sum_stud, "anak")
# Out:
# Jumlah anak yang meningkat skor ujiannya adalah 143 anak

# %% [markdown]
# **8. Jumlah anak yang melakukan extra educational support (les) sesuai free timenya**
#
#   schoolsup - extra educational support (binary: yes or no)
#
#   freetime - free time after school (numeric: from 1 - very low to 5 - very high)

# %%
#grouping by freetime to get info about number of student who have schoolsup for each category
df.groupby("freetime")["schoolsup"].count()
# Out:
# freetime
# 1     19
# 2     64
# 3    157
# 4    115
# 5     40
# Name: schoolsup, dtype: int64

# %%
df.groupby("freetime").agg({"schoolsup": 'count'})
# Out:
#           schoolsup
# freetime
# 1                19
# 2                64
# 3               157
# 4               115
# 5                40

# %% [markdown]
# **9. Nilai rata-rata dengan bobot dari semua ujian (first 25%, second 25%, final 50%)**

# %%
#set variable
value = df["G1"]*0.25 + df["G2"]*0.25 + df["G3"]*0.5
mean_sc = round(value.mean(), 2)
print("Nilai rata-rata dari keseluruhan ujian adalah", mean_sc)
# Out:
# Nilai rata-rata dari keseluruhan ujian adalah 10.61

# %%
#input new column to add info about mean score of each student
df["meansc"] = value

# %%
df.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... higher internet  freetime  goout  Dalc absences  G1  G2  G3 meansc
# 0  ...    yes       no         3      4     1        6   5   6   6   5.75
# ...

# %% [markdown]
# **10. Deskripsi profil (minimal 3 fitur) dari 50 anak-anak yang mendapatkan nilai tertinggi**

# %%
#create new dataframe that contains 50 first rank by mean score
df1 = df.iloc[:50, :].sort_values("meansc", ascending = False).reset_index()
df1
# Out:
#     index school sex  age address famsize Pstatus  Medu  Fedu      Mjob  ...  \
# 0      47     GP   M   16       U     GT3       T     4     3    health  ...
# 1      42     GP   M   15       U     GT3       T     4     4  services  ...
# 2       8     GP   M   15       U     LE3       A     3     2  services  ...
# 3      36     GP   M   15       U     LE3       T     4     3   teacher  ...
# 4      31     GP   M   15       U     GT3       T     4     4  services  ...
# 5      32     GP   M   15       R     GT3       T     4     3   teacher  ...
# 6      22     GP   M   16       U     LE3       T     4     2   teacher  ...
# 7      14     GP   M   15       U     GT3       A     2     2     other  ...
# 8      37     GP   M   16       R     GT3       A     4     4     other  ...
# 9      27     GP   M   15       U     GT3       T     4     2    health  ...
# 10      5     GP   M   16       U     LE3       T     4     3  services  ...
# ...

# %% [markdown]
# school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
#
# sex - student's sex (binary: 'F' - female or 'M' - male)
#
# freetime - free time after school (numeric: from 1 - very low to 5 - very high)
#
# absences - number of school absences (numeric: from 0 to 93)
#
# studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)

# %%
#describe some feature of each 50 first rank
df1.loc[:, ["school", "sex", "meansc", "freetime", "absences", "studytime"]]
# Out:
#    school sex  meansc  freetime  absences  studytime
# 0      GP   M   19.50         2         4          4
# 1      GP   M   18.25         3         2          2
# 2      GP   M   18.00         2         0          2
# 3      GP   M   16.75         4         2          3
# 4      GP   M   16.75         3         0          2
# 5      GP   M   16.25         5         0          2
# 6      GP   M   15.50         5         2          2
# 7      GP   M   15.50         5         0          3
# 8      GP   M   15.25         4         7          3
# 9      GP   M   15.25         2         4          1
# 10     GP   M   15.00         4        10          2
# 11     GP   M   14.75         5         0          2
# 12     GP   F   14.75         2         2          3
# 13     GP   M   14.50         3         2          2
# 14     GP   M   14.25         4         0          2
# 15     GP   M   14.25         4         0          1
# 16     GP   M   14.00         3         2          1
# ...

# %% [markdown]
# sex - student's sex (binary: 'F' - female or 'M' - male)
#
# school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
#
# age - student's age (numeric: from 15 to 22)
#
# health - current health status (numeric: from 1 - very bad to 5 - very good)
#
# failures - number of past class failures (numeric: n if 1<=n<3, else 4)
#
# absences - number of school absences (numeric: from 0 to 93)

# %%
df1.loc[:, ["sex", "school", "age", "Dalc", "failures", "absences"]]
# Out:
#    sex school  age  Dalc  failures  absences
# 0    M     GP   16     1         0         4
# 1    M     GP   15     1         0         2
# 2    M     GP   15     1         0         0
# 3    M     GP   15     1         0         2
# 4    M     GP   15     1         0         0
# 5    M     GP   15     1         0         0
# 6    M     GP   16     1         0         2
# 7    M     GP   15     1         0         0
# 8    M     GP   16     1         0         7
# 9    M     GP   15     2         0         4
# 10   M     GP   16     1         0        10
# 11   M     GP   15     1         0         0
# 12   F     GP   15     1         0         2
# 13   M     GP   15     2         0         2
# 14   M     GP   15     1         0         0
# 15   M     GP   15     1         0         0
# 16   M     GP   15     1         0         2
# 17   F     GP   16     1         0         4
# 18   M     GP   16     1         0         0
# 19   F     GP   16     1         0         6
# ...

# %%
#describe descriptive statistics of numerical data
df1.describe()
# Out:
#           index        age       Medu       Fedu  traveltime  studytime  \
# count  50.00000  50.000000  50.000000  50.000000   50.000000   50.00000
# mean   24.50000  15.540000   3.200000   2.920000    1.260000    1.94000
# std    14.57738   0.705951   0.947607   0.965528    0.527218    0.71171
# min     0.00000  15.000000   1.000000   1.000000    1.000000    1.00000
# 25%    12.25000  15.000000   2.000000   2.000000    1.000000    1.25000
# 50%    24.50000  15.000000   4.000000   3.000000    1.000000    2.00000
# 75%    36.75000  16.000000   4.000000   4.000000    1.000000    2.00000
# max    49.00000  18.000000   4.000000   4.000000    3.000000    4.00000
#
#         failures  freetime      goout       Dalc   absences         G1  \
# count  50.000000  50.00000  50.000000  50.000000  50.000000  50.000000
# mean    0.220000   3.28000   2.620000   1.260000   4.480000  11.360000
# std     0.678835   1.03095   1.085902   0.694292   5.357581   3.718459
# ...

# %%
#describe descriptive statistics of categorical data
df1.describe(include=["object", "bool"])
# Out:
#        school sex address famsize Pstatus   Mjob   Fjob reason guardian  \
# count      50  50      50      50      50     50     50     50       50
# unique      1   2       2       2       2      5      5      4        3
# top        GP   M       U     GT3       T  other  other   home   mother
# freq       50  29      45      34      42     16     26     20       37
#
#        schoolsup famsup paid activities nursery higher internet
# count         50     50   50         50      50     50       50
# unique         2      2    2          2       2      1        2
# top           no    yes   no        yes     yes    yes      yes
# freq          38     40   27         28      42     50       43

# %% [markdown]
# meansc - mean score (25%G1 + 25%G2 + 50%G3)
#
# studytime - weekly study time
#
# freetime - free time after school
#
# absences - number of school absences
#
# failures - number of past class failures

# %%
df1.groupby(['school', 'sex']).agg({'meansc':['max', 'min', 'mean', 'median'], 'studytime': ['min', 'max', 'mean'], 'freetime': ['min', 'max', 'mean'],'absences': ['min', 'max', 'mean'], 'failures': ['min', 'max', 'mean']})
# Out:
#            meansc                         studytime               freetime  \
#               max   min       mean median       min max      mean      min
# school sex
# GP     F    14.75  5.50   9.511905   9.00         1   3  2.047619        1
#        M    19.50  5.25  13.568966  14.25         1   4  1.862069        1
#
#                          absences              failures
#            max      mean      min max     mean      min max      mean
# school sex
# GP     F     5  2.857143        0  25  6.52381        0   3  0.380952
#        M     5  3.586207        0  16  3.00000        0   3  0.103448

# %% [markdown]
# health - current health status
#
# goout - going out with friends

# %%
pd.pivot_table(df1,index = 'sex',values = ['Dalc', 'goout'] ,aggfunc = ['mean', 'min', 'max'])
# Out:
#          mean            min        max
#          Dalc     goout Dalc goout Dalc goout
# sex
# F    1.095238  2.666667    1     1    2     5
# M    1.379310  2.586207    1     1    5     5
